# %%
import pandas as pd
import numpy as np
import datapungi_fed as dpf
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
bit = dpf('CBBTCUSD')

# %%
# bit is a one column data frame
type(bit), bit.shape
# Out:
# (pandas.core.frame.DataFrame, (1941, 1))

# %%
plt.figure(figsize = (20, 8))
sns.lineplot(data = bit)
plt.grid()
plt.axvline('2020-1', alpha = 0.6, linestyle = '--', color = 'r')
plt.xticks(rotation=45)
# Out:
# (array([735234., 735599., 735964., 736330., 736695., 737060., 737425.]),
#  <a list of 7 Text xticklabel objects>)

# %%
prediction_days = 30
bit['prediction'] = bit.shift(-prediction_days)

# %%
# the shifting method results in last 30 rows missing
bit.tail()
# Out:
#             CBBTCUSD  prediction
# date
# 2020-04-23   7479.06         NaN
# 2020-04-24   7514.64         NaN
# 2020-04-25   7535.69         NaN
# 2020-04-26   7765.79         NaN
# 2020-04-27   7773.00         NaN

# %%
bit.shape
# Out:
# (1941, 2)
